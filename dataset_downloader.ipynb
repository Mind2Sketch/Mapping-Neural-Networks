# %%
# !pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in /home/m2s/mind2sketch/venv/lib/python3.12/site-packages (1.0.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /home/m2s/mind2sketch/venv/lib/python3.12/site-packages (from kagglehub) (0.1.16)
# Requirement already satisfied: packaging in /home/m2s/mind2sketch/venv/lib/python3.12/site-packages (from kagglehub) (26.0)
# Requirement already satisfied: pyyaml in /home/m2s/mind2sketch/venv/lib/python3.12/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /home/m2s/mind2sketch/venv/lib/python3.12/site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in /home/m2s/mind2sketch/venv/lib/python3.12/site-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in /home/m2s/mind2sketch/venv/lib/python3.12/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (7.34.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/m2s/mind2sketch/venv/lib/python3.12/site-packages (from requests->kagglehub) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/m2s/mind2sketch/venv/lib/python3.12/site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/m2s/mind2sketch/venv/lib/python3.12/site-packages (from requests->kagglehub) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/m2s/mind2sketch/venv/lib/python3.12/site-packages (from requests->kagglehub) (2026.2.25)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("denislukovnikov/ffhq256-images-only")

print("Path to dataset files:", path)
# Out:
# Downloading to /home/m2s/.cache/kagglehub/datasets/denislukovnikov/ffhq256-images-only/1.archive...
# 100%|██████████████████████████████████| 6.91G/6.91G [05:26<00:00, 22.7MB/s]
# Extracting files...
# Path to dataset files: /home/m2s/.cache/kagglehub/datasets/denislukovnikov/ffhq256-images-only/versions/1

# %%
# !rsync -ah --info=progress2 {path}/ ./ffhq/
# Out:
#           4.04G  54%    1.47GB/s    0:00:02 (xfr#38179, to-chk=31821/70002)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#           7.41G 100%    1.51GB/s    0:00:04 (xfr#70000, to-chk=0/70002)

# %%
# !ls
# Out:
# 3_Mappers.ipynb  dataset_downloader.ipynb  stylegan2-ada-pytorch
# 5_Mappers.ipynb  ffhq

# %%
# !du -sh ffhq
# Out:
# 7.1G	ffhq

# %%
# !rm -rf {path}
